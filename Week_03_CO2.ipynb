# %% [markdown]
# <a href="https://colab.research.google.com/github/Samanvai22/dataviz-exercises-Govikar-Samanvai/blob/main/Week_03_CO2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 3 — Class Exercise
# #Line Charts & Slopegraphs: CO2 Emissions

# %%
print("Countries:", df['Country'].unique())
print("\nCO2 range:", df['CO2_Mt'].min(), "to", df['CO2_Mt'].max(), "Mt")
print("\nRegional averages (2022):")
print(df[df['Year']==2022].groupby('Region')['CO2_Mt'].mean().sort_values(ascending=False).round(1))
# Out:
# Countries: ['United States' 'China' 'India' 'Germany' 'United Kingdom' 'France'
#  'Brazil' 'Japan' 'Canada' 'Australia' 'South Korea' 'Russia'
#  'South Africa' 'Mexico' 'Indonesia']
#
# CO2 range: 125.3 to 12409.5 Mt
#
# Regional averages (2022):
# Region
# Asia             3531.1
# North America    2393.8
# Latin America     629.2
# Africa            534.4
# Europe            496.5
# Oceania           493.7
# Name: CO2_Mt, dtype: float64

# %% [markdown]
# # Task 1 — Multi-series Line Chart

# %%
asia = df[df['Region'] == 'Asia'].copy()
highlight = 'China'

# %%
fig = go.Figure()
for country in asia['Country'].unique():
    d = asia[asia['Country'] == country]

    if country == highlight:
        fig.add_trace(go.Scatter(
            x=d['Year'],
            y=d['CO2_Mt'],
            mode='lines',
            name=country,
            line=dict(color='#2E75B6', width=3)
        ))
    else:
        fig.add_trace(go.Scatter(
            x=d['Year'],
            y=d['CO2_Mt'],
            mode='lines',
            name=country,
            line=dict(color='#DDDDDD', width=1),
            showlegend=False
        ))

# %%
last = asia[(asia['Country'] == highlight) & (asia['Year'] == asia['Year'].max())]

fig.add_annotation(
    x=last['Year'].values[0],
    y=last['CO2_Mt'].values[0],
    text=f"<b>{highlight}</b>",
    showarrow=False,
    xanchor='left',
    xshift=6,
    font=dict(color='#2E75B6', size=12, family='Arial')
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="05049781-3a6d-468a-a57e-1071c572a1a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05049781-3a6d-468a-a57e-1071c572a1a5")) {                    Plotly.newPlot(                        "05049781-3a6d-468a-a57e-1071c572a1a5",                        [{"line":{"color":"#2E75B6","width":3},"mode":"lines","name":"China","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[3513.8,3951.7,4312.0,4691.9,5078.9,5467.8,5974.0,6322.7,6673.0,7052.6,7542.8,7972.2,8365.2,8641.3,9078.4,9466.5,9887.0,10356.9,10794.9,11125.3,11454.8,11897.5,12409.5],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"India","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[901.6,974.6,1056.0,1146.4,1205.4,1291.0,1396.5,1465.9,1541.7,1637.4,1687.4,1774.1,1865.3,1944.7,1994.5,2092.4,2177.1,2267.3,2344.6,2418.7,2465.5,2579.5,2661.1],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"Japan","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[1165.7,1219.6,1135.5,1131.4,1151.1,1126.7,1100.8,1133.1,1050.3,1061.4,1064.1,1041.7,1005.1,990.9,1010.4,996.6,967.4,925.1,916.6,914.5,902.8,898.1,865.1],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"South Korea","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[438.1,481.5,490.6,490.8,494.6,537.2,539.0,566.1,570.0,585.4,595.9,620.6,631.1,649.6,646.2,686.5,704.0,706.0,738.5,750.8,755.8,777.3,789.5],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"Indonesia","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[382.8,400.4,430.7,453.8,482.6,501.9,533.0,551.8,586.6,602.5,614.5,647.3,680.1,717.7,736.3,738.2,768.8,813.7,834.8,872.3,876.5,898.5,930.5],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %%
#declutter
fig.update_layout(
    title="China’s CO2 emissions surged since 2000 — no other Asian country is close",
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=13),

    yaxis=dict(
        title='CO2 Emissions (Mt)',
        gridcolor='#EEEEEE'
    ),

    xaxis=dict(
        showgrid=False,
        title=''
    ),

    margin=dict(l=60, r=80, t=60, b=40)
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e03181e0-f8f9-4e60-8720-3a2c6ee393c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e03181e0-f8f9-4e60-8720-3a2c6ee393c4")) {                    Plotly.newPlot(                        "e03181e0-f8f9-4e60-8720-3a2c6ee393c4",                        [{"line":{"color":"#2E75B6","width":3},"mode":"lines","name":"China","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[3513.8,3951.7,4312.0,4691.9,5078.9,5467.8,5974.0,6322.7,6673.0,7052.6,7542.8,7972.2,8365.2,8641.3,9078.4,9466.5,9887.0,10356.9,10794.9,11125.3,11454.8,11897.5,12409.5],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"India","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[901.6,974.6,1056.0,1146.4,1205.4,1291.0,1396.5,1465.9,1541.7,1637.4,1687.4,1774.1,1865.3,1944.7,1994.5,2092.4,2177.1,2267.3,2344.6,2418.7,2465.5,2579.5,2661.1],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"Japan","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[1165.7,1219.6,1135.5,1131.4,1151.1,1126.7,1100.8,1133.1,1050.3,1061.4,1064.1,1041.7,1005.1,990.9,1010.4,996.6,967.4,925.1,916.6,914.5,902.8,898.1,865.1],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"South Korea","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[438.1,481.5,490.6,490.8,494.6,537.2,539.0,566.1,570.0,585.4,595.9,620.6,631.1,649.6,646.2,686.5,704.0,706.0,738.5,750.8,755.8,777.3,789.5],"type":"scatter"},{"line":{"color":"#DDDDDD","width":1},"mode":"lines","name":"Indonesia","showlegend":false,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[382.8,400.4,430.7,453.8,482.6,501.9,533.0,551.8,586.6,602.5,614.5,647.3,680.1,717.7,736.3,738.2,768.8,813.7,834.8,872.3,876.5,898.5,930.5],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %% [markdown]
# # Task 2 — Slopegraph: Regional Change 2000 vs 2022

# %%
regional = df.groupby(['Region', 'Year'])['CO2_Mt'].mean().reset_index()
sg = regional[regional['Year'].isin([2000, 2022])].copy()

# %%
changes = sg.groupby('Region')['CO2_Mt'].agg(['first', 'last'])

color_map = {
    region: '#2E75B6' if row['last'] > row['first'] else '#F28E2B'
    for region, row in changes.iterrows()
}

# %%
fig = px.line(
    sg.sort_values('Year'),
    x='Year',
    y='CO2_Mt',
    color='Region',
    color_discrete_map=color_map,
    markers=True
)

# %%
for region in sg['Region'].unique():
    d = sg[sg['Region'] == region].sort_values('Year')

    fig.update_traces(
        selector=dict(name=region),
        mode='lines+markers+text',
        text=[
            f"{d['CO2_Mt'].iloc[0]:.0f}",
            f"{region}<br>{d['CO2_Mt'].iloc[1]:.0f}"
        ],
        textposition=['middle left', 'middle right'],
        textfont=dict(size=10, family='Arial'),
        showlegend=False
    )

# %%
fig.update_layout(
    title="Asia shows the strongest growth in emissions since 2000; Europe declines",
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=12),

    xaxis=dict(
        tickvals=[2000, 2022],
        ticktext=['2000', '2022'],
        showgrid=False,
        range=[1995, 2028]
    ),

    yaxis=dict(
        showgrid=False,
        showticklabels=False,
        title=''
    ),

    margin=dict(l=80, r=120, t=60, b=40)
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8d644702-d055-4896-bc09-2f2e6492536f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d644702-d055-4896-bc09-2f2e6492536f")) {                    Plotly.newPlot(                        "8d644702-d055-4896-bc09-2f2e6492536f",                        [{"hovertemplate":"Region=Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","line":{"color":"#2E75B6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Africa","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[425.4,534.4],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["425","Africa\u003cbr\u003e534"],"textposition":["middle left","middle right"]},{"hovertemplate":"Region=Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","line":{"color":"#2E75B6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Asia","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[1280.4,3531.1400000000003],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["1280","Asia\u003cbr\u003e3531"],"textposition":["middle left","middle right"]},{"hovertemplate":"Region=Latin America\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America","line":{"color":"#2E75B6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Latin America","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[419.85,629.15],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["420","Latin America\u003cbr\u003e629"],"textposition":["middle left","middle right"]},{"hovertemplate":"Region=Europe\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","line":{"color":"#F28E2B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Europe","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[834.925,496.5],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["835","Europe\u003cbr\u003e496"],"textposition":["middle left","middle right"]},{"hovertemplate":"Region=Oceania\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","line":{"color":"#2E75B6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Oceania","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[378.4,493.7],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["378","Oceania\u003cbr\u003e494"],"textposition":["middle left","middle right"]},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2_Mt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","line":{"color":"#F28E2B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"North America","orientation":"v","showlegend":false,"x":[2000,2022],"xaxis":"x","y":[3223.6000000000004,2393.7999999999997],"yaxis":"y","type":"scatter","textfont":{"family":"Arial","size":10},"text":["3224","North America\u003cbr\u003e2394"],"textposition":["middle left","middle right"]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv('/content/co2_emissions.csv')
print(f"Loaded: {len(df)} rows | Countries: {df['Country'].nunique()} | Years: {df['Year'].min()}-{df['Year'].max()}")
print(df.head())
# Out:
# Loaded: 345 rows | Countries: 15 | Years: 2000-2022
#          Country         Region  Year  CO2_Mt  CO2_per_capita
# 0  United States  North America  2000  5857.6            1.32
# 1  United States  North America  2001  5724.0            1.26
# 2  United States  North America  2002  5652.8            1.11
# 3  United States  North America  2003  5592.8            1.29
# 4  United States  North America  2004  5743.2            1.12
